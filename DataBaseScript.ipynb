-- %% [markdown]
-- # [ProyectoSalesDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ProyectoSalesDB]    Script Date: 8/13/2025 11:51:20 PM ******/
CREATE DATABASE [ProyectoSalesDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ProyectoSalesDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.RIC\MSSQL\DATA\ProyectoSalesDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ProyectoSalesDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.RIC\MSSQL\DATA\ProyectoSalesDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [ProyectoSalesDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ProyectoSalesDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ProyectoSalesDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ProyectoSalesDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ProyectoSalesDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [ProyectoSalesDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ProyectoSalesDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET RECOVERY FULL 
GO
ALTER DATABASE [ProyectoSalesDB] SET  MULTI_USER 
GO
ALTER DATABASE [ProyectoSalesDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ProyectoSalesDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ProyectoSalesDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ProyectoSalesDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ProyectoSalesDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [ProyectoSalesDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'ProyectoSalesDB', N'ON'
GO
ALTER DATABASE [ProyectoSalesDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [ProyectoSalesDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[VentaItemInput]

-- %%
USE [ProyectoSalesDB]
GO

-- %%
/****** Object:  UserDefinedTableType [dbo].[VentaItemInput]    Script Date: 8/13/2025 11:51:20 PM ******/
CREATE TYPE [dbo].[VentaItemInput] AS TABLE(
	[ProductoId] [int] NOT NULL,
	[Cantidad] [int] NOT NULL,
	[PrecioUnitario] [decimal](18, 2) NULL,
	CHECK (([Cantidad]>(0)))
)
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 8/13/2025 11:51:20 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](120) NOT NULL,
	[Descripcion] [nvarchar](255) NULL,
	[Precio] [decimal](18, 2) NOT NULL,
	[Stock] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 8/13/2025 11:51:20 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[nombres] [varchar](50) NOT NULL,
	[apellidos] [varchar](50) NOT NULL,
	[correo] [varchar](100) NOT NULL,
	[username] [varchar](100) NOT NULL,
	[fecha_creacion] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VentaItems]

-- %%
/****** Object:  Table [dbo].[VentaItems]    Script Date: 8/13/2025 11:51:20 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[VentaItems](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[VentaId] [int] NOT NULL,
	[ProductoId] [int] NOT NULL,
	[Cantidad] [int] NOT NULL,
	[PrecioUnitario] [decimal](18, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ventas]

-- %%
/****** Object:  Table [dbo].[Ventas]    Script Date: 8/13/2025 11:51:20 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ventas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [datetime] NOT NULL,
	[Cliente] [nvarchar](120) NOT NULL,
	[Total] [decimal](18, 2) NOT NULL,
	[ListaProductos] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Ventas__Fecha__3B75D760]

-- %%
ALTER TABLE [dbo].[Ventas] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [dbo].[usp_VentaCrear]

-- %%
/****** Object:  StoredProcedure [dbo].[usp_VentaCrear]    Script Date: 8/13/2025 11:51:20 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE   PROCEDURE [dbo].[usp_VentaCrear]
    @Cliente NVARCHAR(120),
    @Items   dbo.VentaItemInput READONLY,
    @VentaId INT OUTPUT
AS
BEGIN
    SET NOCOUNT ON;
    SET XACT_ABORT ON;

    BEGIN TRY
        BEGIN TRAN;

        -- 1) Validar stock
        IF EXISTS (
            SELECT 1
            FROM @Items i
            JOIN dbo.Productos p ON p.Id = i.ProductoId
            WHERE i.Cantidad > p.Stock
        )
        BEGIN
            THROW 50001, 'Stock insuficiente para uno o más productos.', 1;
        END

        -- 2) Crear venta (Total 0)
        INSERT INTO dbo.Ventas (Cliente, Total)
        VALUES (@Cliente, 0);

        SET @VentaId = SCOPE_IDENTITY();

        -- 3) Insertar ítems (si PrecioUnitario es NULL, usar p.Precio)
        INSERT INTO dbo.VentaItems (VentaId, ProductoId, Cantidad, PrecioUnitario)
        SELECT
            @VentaId,
            i.ProductoId,
            i.Cantidad,
            ISNULL(i.PrecioUnitario, p.Precio)
        FROM @Items i
        JOIN dbo.Productos p ON p.Id = i.ProductoId;

        -- 4) Descontar stock
        ;WITH mov AS (
            SELECT ProductoId, SUM(Cantidad) Cantidad
            FROM @Items
            GROUP BY ProductoId
        )
        UPDATE p
        SET p.Stock = p.Stock - m.Cantidad
        FROM dbo.Productos p
        JOIN mov m ON m.ProductoId = p.Id;

        -- 5) Recalcular total
        UPDATE v
        SET v.Total = t.Total
        FROM dbo.Ventas v
        CROSS APPLY (
            SELECT SUM(vi.Cantidad * vi.PrecioUnitario) AS Total
            FROM dbo.VentaItems vi
            WHERE vi.VentaId = @VentaId
        ) t
        WHERE v.Id = @VentaId;

        COMMIT;
    END TRY
    BEGIN CATCH
        IF XACT_STATE() <> 0 ROLLBACK;
        THROW;
    END CATCH
END
GO

-- %% [markdown]
-- # [ProyectoSalesDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ProyectoSalesDB] SET  READ_WRITE 
GO
